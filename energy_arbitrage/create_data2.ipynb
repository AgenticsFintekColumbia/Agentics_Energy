# %%
"""
Corrected Dataset Generator - Matches Runtime DayInputs Format
Uses exact field names and output schema from runtime
"""

import json
import numpy as np
import pandas as pd
from pathlib import Path
from typing import List, Dict

from agentic_energy.schemas import BatteryParams, DayInputs, SolveRequest, SolveResponse
from agentic_energy.data_loader import BatteryDataLoader
from agentic_energy.milp.milp_mcp_server import solve_daily_milp

from agentic_energy.milp.milp_mcp_server import solve_daily_milp
import asyncio

class CorrectedDatasetGenerator:
    """Generate training data matching runtime DayInputs/SolveResponse format"""
    
    def __init__(self, battery_params: BatteryParams):
        self.battery_params = battery_params
        self.instruction = self._create_instruction()
    
    def _create_instruction(self) -> str:
        """Create instruction matching runtime format"""
        bp = self.battery_params
        
        # Simplified but compatible instruction
        return f"""Solve battery optimization using forecast data to minimize costs.

BATTERY: {bp.capacity_kwh:.2f} kWh, {bp.cmax_kw:.2f} kW charge/discharge, efficiency {bp.eta_c}/{bp.eta_d}
INITIAL SOC: {bp.soc_init:.2f}, TARGET: {bp.soc_target:.2f}, RANGE: [{bp.soc_min:.2f}, {bp.soc_max:.2f}]

CONSTRAINTS:
- SOC[t+1] = SOC[t] + (charge[t]*{bp.eta_c} - discharge[t]/{bp.eta_d})*dt/{bp.capacity_kwh}
- 0 ≤ charge[t] ≤ {bp.cmax_kw}, 0 ≤ discharge[t] ≤ {bp.dmax_kw}
- {bp.soc_min} ≤ SOC[t] ≤ {bp.soc_max}
- charge[t] * discharge[t] = 0 (no simultaneous)
- SOC[0] = {bp.soc_init}, SOC[T] ≥ {bp.soc_target}

STRATEGY: Use prices_buy_forecast, prices_sell_forecast, demand_kw_forecast to decide charge/discharge.
Charge when forecast price < p25, discharge when > p75. Calculate cost with actual prices.

OUTPUT: JSON with status, message, objective_cost, charge_kw, discharge_kw, import_kw, export_kw, soc, decision."""
    
    def create_input(
        self,
        date: str,
        prices: np.ndarray,
        demand: np.ndarray,
        dataset_name: str = None
    ) -> str:
        """Create input in DayInputs format"""
        
        # Calculate stats for strategy hints
        p25 = float(np.percentile(prices, 25))
        p75 = float(np.percentile(prices, 75))
        
        # Exact DayInputs format
        input_dict = {
            "prices_buy": [round(float(p), 2) for p in prices],
            "prices_sell": [round(float(p), 2) for p in prices],
            "demand_kw": [round(float(d), 2) for d in demand],
            "allow_export": True,
            "dt_hours": 1.0,
            "prices_buy_forecast": [round(float(p), 2) for p in prices],
            "prices_sell_forecast": [round(float(p), 2) for p in prices],
            "demand_kw_forecast": [round(float(d), 2) for d in demand],
            "p25": round(p25, 2),
            "p75": round(p75, 2)
        }
        
        return json.dumps(input_dict, separators=(',', ':'))
    
    def create_output(
        self,
        milp_solution: SolveResponse,
        prices: np.ndarray
    ) -> str:
        """Create output in SolveResponse format"""
        
        T = len(prices)
        charge = milp_solution.charge_kw or [0.0] * T
        discharge = milp_solution.discharge_kw or [0.0] * T
        soc = milp_solution.soc or [self.battery_params.soc_init] * (T + 1)
        cost = milp_solution.objective_cost or 0.0
        
        # Calculate import/export
        import_kw = milp_solution.import_kw or [0.0] * T
        export_kw = milp_solution.export_kw or [0.0] * T
        
        # Calculate decision
        decision = [1.0 if c > 0.01 else (-1.0 if d > 0.01 else 0.0) 
                   for c, d in zip(charge, discharge)]
        
        # Brief strategy message
        charge_hours = sum(1 for d in decision if d > 0)
        discharge_hours = sum(1 for d in decision if d < 0)
        
        if charge_hours > 0 and discharge_hours > 0:
            msg = f"Charge {charge_hours}h, discharge {discharge_hours}h"
        elif charge_hours > 0:
            msg = f"Charge {charge_hours}h only"
        elif discharge_hours > 0:
            msg = f"Discharge {discharge_hours}h only"
        else:
            msg = "No arbitrage"
        
        # Match SolveResponse schema exactly
        output_dict = {
            "status": "success",
            "message": msg,
            "objective_cost": round(float(cost), 2),
            "charge_kw": [round(float(c), 2) for c in charge],
            "discharge_kw": [round(float(d), 2) for d in discharge],
            "import_kw": [round(float(i), 2) for i in import_kw],
            "export_kw": [round(float(e), 2) for e in export_kw],
            "soc": [round(float(s), 4) for s in soc],
            "decision": [float(d) for d in decision]
        }
        
        return json.dumps(output_dict, separators=(',', ':'))
    
    def create_training_example(
        self,
        date: str,
        prices: np.ndarray,
        demand: np.ndarray,
        milp_solution: SolveResponse,
        dataset_name: str = None
    ) -> Dict[str, str]:
        """Create complete training example"""
        
        return {
            "instruction": self.instruction,
            "input": self.create_input(date, prices, demand, dataset_name),
            "output": self.create_output(milp_solution, prices)
        }


def generate_corrected_dataset(
    dataset_name: str,
    split: str,
    battery_params: BatteryParams,
    data_dir: str = "./agentic_energy/data",
    output_dir: str = "./datasets_corrected",
    max_days: int = None
) -> List[Dict[str, str]]:
    """Generate corrected dataset"""
    
    print(f"\n{'='*80}")
    print(f"GENERATING: {dataset_name.upper()} ({split})")
    print(f"{'='*80}")
    
    from agentic_energy.data_loader import EnergyDataLoader
    
    # Load data
    loader = EnergyDataLoader(region=dataset_name.upper(), data_version="actual")
    data = loader.load_region_data()
    
    # Split data
    split_idx = int(len(data) * 0.5)
    if split == "train":
        data_subset = data[:split_idx]
    else:
        data_subset = data[split_idx:]
    
    # Limit if requested
    if max_days:
        data_subset = data_subset[:max_days * 24]
    
    generator = CorrectedDatasetGenerator(battery_params)
    examples = []
    
    # Process in 24-hour chunks
    for i in range(0, len(data_subset) - 23, 24):
        day_data = data_subset[i:i+24]
        
        prices = np.array([d.prices for d in day_data], dtype=float)
        demand = np.array([d.consumption for d in day_data], dtype=float)
        date = day_data[0].timestamps[:10] if hasattr(day_data[0], 'timestamps') else f"day_{i//24}"
        
        # Create DayInputs
        day_inputs = DayInputs(
            prices_buy=prices.tolist(),
            prices_sell=prices.tolist(),
            demand_kw=demand.tolist(),
            allow_export=True,
            dt_hours=1.0,
            prices_buy_forecast=prices.tolist(),
            prices_sell_forecast=prices.tolist(),
            demand_kw_forecast=demand.tolist()
        )
        
        # Solve with MILP
        req = SolveRequest(
            battery=battery_params,
            day=day_inputs,
            solver=None,
            solver_opts=None
        )
        
        try:
            # milp_solution = solve_daily_milp(req)
            milp_solution = asyncio.run(solve_daily_milp(req)) if asyncio.iscoroutinefunction(solve_daily_milp) else solve_daily_milp(req)

            
            if milp_solution.status == "success":
                example = generator.create_training_example(
                    date, prices, demand, milp_solution, dataset_name
                )
                examples.append(example)
                
                if len(examples) % 50 == 0:
                    print(f"  Generated {len(examples)} examples...")
        except Exception as e:
            print(f"  Skipping day {i//24}: {e}")
            continue
    
    # Save
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)
    
    filename = f"{dataset_name}_{split}_corrected.json"
    filepath = output_path / filename
    
    with open(filepath, 'w') as f:
        json.dump(examples, f, indent=2)
    
    print(f"\n✓ Saved {len(examples)} examples to {filepath}")
    print(f"  Size: {filepath.stat().st_size / (1024**2):.2f} MB")
    
    return examples


def analyze_token_lengths(dataset_path: str):
    """Analyze token lengths"""
    import tiktoken
    
    enc = tiktoken.get_encoding("cl100k_base")
    
    with open(dataset_path, 'r') as f:
        data = json.load(f)
    
    lengths = []
    for ex in data:
        full_text = f"{ex['instruction']}\n\nINPUT:\n{ex['input']}\n\nOUTPUT:\n{ex['output']}"
        tokens = len(enc.encode(full_text))
        lengths.append(tokens)
    
    lengths = np.array(lengths)
    
    print(f"\n{'='*80}")
    print("TOKEN LENGTH ANALYSIS")
    print(f"{'='*80}")
    print(f"Dataset: {dataset_path}")
    print(f"Examples: {len(data)}")
    print(f"\nToken Statistics:")
    print(f"  Min:    {int(np.min(lengths)):,}")
    print(f"  Max:    {int(np.max(lengths)):,}")
    print(f"  Mean:   {int(np.mean(lengths)):,}")
    print(f"  Median: {int(np.median(lengths)):,}")
    print(f"  P95:    {int(np.percentile(lengths, 95)):,}")
    print(f"  P99:    {int(np.percentile(lengths, 99)):,}")
    
    for limit in [2048, 4096, 8192]:
        truncated = np.sum(lengths > limit)
        pct = 100 * truncated / len(lengths)
        print(f"\n  With max_seq_length={limit}:")
        print(f"    Truncated: {truncated}/{len(lengths)} ({pct:.1f}%)")
    
    # Show example
    print(f"\n{'='*80}")
    print("EXAMPLE (First Training Instance)")
    print(f"{'='*80}")
    ex = data[0]
    print(f"\nInstruction length: {len(ex['instruction'])} chars")
    print(f"Input length: {len(ex['input'])} chars")
    print(f"Output length: {len(ex['output'])} chars")
    print(f"Total tokens: {lengths[0]:,}")
    print(f"\n--- INPUT SAMPLE (first 200 chars) ---")
    print(ex['input'][:200] + "...")
    print(f"\n--- OUTPUT SAMPLE (first 200 chars) ---")
    print(ex['output'][:200] + "...")


if __name__ == "__main__":
    # Battery configuration - matches your setup
    battery_params = BatteryParams(
        capacity_kwh=49.44,
        cmax_kw=12.36,
        dmax_kw=12.36,
        eta_c=0.95,
        eta_d=0.95,
        soc_init=0.5,
        soc_min=0.0,
        soc_max=1.0,
        soc_target=0.5
    )
    
    # Generate datasets
    datasets_to_generate = ['italy', 'germany', 'caiso']
    
    all_train = []
    all_test = []
    
    for dataset_name in datasets_to_generate:
        battery_params.soc_init = 0.5
        
        # Train
        train_data = generate_corrected_dataset(
            dataset_name=dataset_name,
            split='train',
            battery_params=battery_params,
            data_dir="./agentic_energy/data",
            output_dir="./datasets_corrected",
            max_days=None
        )
        all_train.extend(train_data)
        
        # Test
        battery_params.soc_init = 0.5
        test_data = generate_corrected_dataset(
            dataset_name=dataset_name,
            split='test',
            battery_params=battery_params,
            data_dir="./agentic_energy/data",
            output_dir="./datasets_corrected",
            max_days=None
        )
        all_test.extend(test_data)
    
    # Combine
    print(f"\n{'='*80}")
    print("COMBINING DATASETS")
    print(f"{'='*80}\n")
    
    combined_train_path = Path("./datasets_corrected/combined_train_corrected.json")
    combined_test_path = Path("./datasets_corrected/combined_test_corrected.json")
    
    with open(combined_train_path, 'w') as f:
        json.dump(all_train, f, indent=2)
    
    with open(combined_test_path, 'w') as f:
        json.dump(all_test, f, indent=2)
    
    print(f"✓ Combined train: {combined_train_path}")
    print(f"  Examples: {len(all_train)}")
    print(f"  Size: {combined_train_path.stat().st_size / (1024**2):.2f} MB")
    
    print(f"\n✓ Combined test: {combined_test_path}")
    print(f"  Examples: {len(all_test)}")
    print(f"  Size: {combined_test_path.stat().st_size / (1024**2):.2f} MB")
    
    # Analyze
    print(f"\n{'='*80}")
    print("ANALYZING TRAINING DATASET")
    print(f"{'='*80}")
    analyze_token_lengths(str(combined_train_path))
# Out:
# Forecast Engine using device: cpu
# 2025-11-16 02:36:30.665 | DEBUG    | agentics.core.agentics:from_csv:307 - Importing Agentics of type EnergyDataRecord from CSV c:\Users\16467\OneDrive\Desktop\Columbia\Agentics\Another\Agentics_for_EnergyArbitrage_Battery\energy_arbitrage\agentic_energy\data\Italy_data_actual.csv
# 2025-11-16 02:36:30.713 | DEBUG    | agentics.core.llm_connections:get_llm_provider:32 - Available LLM providers: ['gemini', 'openai', 'ollama']. None specified, defaulting to 'ollama'
# 2025-11-16 02:36:30.818 | DEBUG    | agentics.core.agentics:from_csv:307 - Importing Agentics of type EnergyDataRecord from CSV c:\Users\16467\OneDrive\Desktop\Columbia\Agentics\Another\Agentics_for_EnergyArbitrage_Battery\energy_arbitrage\agentic_energy\data\Italy_data_actual.csv
# ================================================================================
# GENERATING: ITALY (train)
# ================================================================================
#   Skipping day 0: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 1: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 2: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 3: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 4: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 5: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 6: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 7: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 8: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 9: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 10: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 11: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 12: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 13: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 14: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 15: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 16: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 17: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 18: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 19: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 20: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 21: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 22: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 23: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 24: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 25: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 26: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 27: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 28: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 29: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 30: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 31: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 32: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 33: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 34: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 35: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 36: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 37: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 38: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 39: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 40: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 41: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 42: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 43: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 44: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 45: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 46: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 47: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 48: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 49: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 50: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 51: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 52: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 53: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 54: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 55: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 56: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 57: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 58: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 59: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 60: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 61: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 62: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 63: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 64: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 65: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 66: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 67: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 68: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 69: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 70: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 71: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 72: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 73: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 74: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 75: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 76: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 77: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 78: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 79: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 80: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 81: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 82: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 83: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 84: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 85: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 86: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 87: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 88: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 89: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 90: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 91: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 92: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 93: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 94: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 95: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 96: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 97: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 98: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 99: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 100: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 101: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 102: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 103: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 104: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 105: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 106: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 107: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 108: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 109: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 110: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 111: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 112: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 113: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 114: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 115: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 116: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 117: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 118: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 119: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 120: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 121: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 122: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 123: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 124: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 125: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 126: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 127: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 128: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 129: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 130: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 131: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 132: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 133: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 134: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 135: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 136: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 137: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 138: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 139: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 140: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 141: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 142: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 143: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 144: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 145: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 146: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 147: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 148: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 149: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 150: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 151: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 152: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 153: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 154: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 155: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 156: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 157: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 158: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 159: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 160: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 161: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 162: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 163: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 164: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 165: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 166: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 167: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 168: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 169: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 170: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 171: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 172: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 173: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 174: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 175: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 176: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 177: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 178: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 179: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 180: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 181: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 182: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 183: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 184: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 185: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 186: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 187: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 188: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 189: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 190: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 191: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 192: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 193: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 194: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 195: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 196: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 197: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 198: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 199: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 200: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 201: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 202: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 203: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 204: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 205: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 206: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 207: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 208: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 209: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 210: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 211: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 212: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 213: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 214: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 215: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 216: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 217: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 218: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 219: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 220: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 221: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 222: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 223: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 224: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 225: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 226: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 227: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 228: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 229: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 230: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 231: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 232: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 233: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 234: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 235: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 236: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 237: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 238: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 239: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 240: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 241: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 242: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 243: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 244: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 245: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 246: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 247: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 248: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 249: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 250: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 251: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 252: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 253: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 254: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 255: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 256: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 257: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 258: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 259: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 260: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 261: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 262: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 263: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 264: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 265: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 266: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 267: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 268: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 269: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 270: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 271: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 272: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 273: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 274: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 275: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 276: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 277: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 278: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 279: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 280: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 281: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 282: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 283: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 284: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 285: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 286: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 287: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 288: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 289: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 290: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 291: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 292: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 293: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 294: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 295: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 296: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 297: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 298: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 299: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 300: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 301: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 302: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 303: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 304: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 305: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 306: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 307: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 308: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 309: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 310: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 311: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 312: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 313: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 314: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 315: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 316: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 317: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 318: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 319: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 320: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 321: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 322: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 323: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 324: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 325: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 326: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 327: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 328: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 329: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 330: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 331: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 332: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 333: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 334: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 335: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 336: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 337: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 338: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 339: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 340: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 341: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 342: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 343: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 344: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 345: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 346: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 347: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 348: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 349: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 350: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 351: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 352: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 353: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 354: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 355: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 356: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 357: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 358: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 359: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 360: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 361: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 362: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 363: solve_daily_milp() missing 1 required positional argument: 'day'
#
# ✓ Saved 0 examples to datasets_corrected\italy_train_corrected.json
#   Size: 0.00 MB
#
# ================================================================================
# GENERATING: ITALY (test)
# ================================================================================
# 2025-11-16 02:36:30.869 | DEBUG    | agentics.core.llm_connections:get_llm_provider:32 - Available LLM providers: ['gemini', 'openai', 'ollama']. None specified, defaulting to 'ollama'
# 2025-11-16 02:36:30.946 | DEBUG    | agentics.core.agentics:from_csv:307 - Importing Agentics of type EnergyDataRecord from CSV c:\Users\16467\OneDrive\Desktop\Columbia\Agentics\Another\Agentics_for_EnergyArbitrage_Battery\energy_arbitrage\agentic_energy\data\Germany_energy_Data.csv
#   Skipping day 0: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 1: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 2: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 3: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 4: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 5: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 6: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 7: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 8: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 9: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 10: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 11: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 12: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 13: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 14: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 15: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 16: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 17: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 18: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 19: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 20: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 21: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 22: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 23: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 24: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 25: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 26: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 27: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 28: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 29: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 30: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 31: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 32: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 33: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 34: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 35: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 36: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 37: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 38: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 39: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 40: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 41: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 42: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 43: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 44: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 45: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 46: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 47: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 48: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 49: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 50: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 51: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 52: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 53: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 54: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 55: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 56: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 57: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 58: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 59: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 60: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 61: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 62: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 63: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 64: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 65: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 66: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 67: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 68: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 69: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 70: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 71: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 72: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 73: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 74: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 75: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 76: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 77: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 78: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 79: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 80: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 81: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 82: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 83: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 84: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 85: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 86: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 87: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 88: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 89: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 90: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 91: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 92: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 93: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 94: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 95: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 96: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 97: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 98: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 99: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 100: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 101: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 102: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 103: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 104: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 105: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 106: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 107: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 108: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 109: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 110: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 111: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 112: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 113: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 114: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 115: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 116: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 117: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 118: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 119: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 120: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 121: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 122: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 123: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 124: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 125: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 126: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 127: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 128: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 129: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 130: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 131: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 132: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 133: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 134: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 135: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 136: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 137: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 138: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 139: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 140: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 141: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 142: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 143: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 144: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 145: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 146: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 147: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 148: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 149: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 150: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 151: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 152: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 153: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 154: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 155: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 156: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 157: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 158: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 159: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 160: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 161: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 162: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 163: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 164: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 165: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 166: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 167: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 168: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 169: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 170: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 171: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 172: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 173: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 174: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 175: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 176: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 177: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 178: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 179: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 180: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 181: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 182: solve_daily_milp() missing 1 required positional argument: 'day'
# ...
#   Skipping day 213: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 214: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 215: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 216: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 217: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 218: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 219: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 220: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 221: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 222: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 223: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 224: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 225: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 226: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 227: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 228: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 229: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 230: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 231: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 232: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 233: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 234: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 235: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 236: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 237: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 238: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 239: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 240: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 241: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 242: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 243: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 244: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 245: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 246: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 247: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 248: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 249: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 250: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 251: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 252: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 253: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 254: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 255: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 256: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 257: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 258: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 259: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 260: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 261: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 262: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 263: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 264: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 265: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 266: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 267: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 268: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 269: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 270: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 271: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 272: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 273: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 274: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 275: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 276: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 277: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 278: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 279: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 280: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 281: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 282: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 283: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 284: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 285: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 286: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 287: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 288: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 289: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 290: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 291: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 292: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 293: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 294: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 295: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 296: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 297: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 298: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 299: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 300: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 301: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 302: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 303: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 304: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 305: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 306: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 307: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 308: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 309: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 310: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 311: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 312: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 313: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 314: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 315: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 316: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 317: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 318: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 319: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 320: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 321: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 322: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 323: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 324: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 325: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 326: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 327: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 328: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 329: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 330: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 331: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 332: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 333: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 334: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 335: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 336: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 337: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 338: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 339: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 340: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 341: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 342: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 343: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 344: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 345: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 346: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 347: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 348: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 349: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 350: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 351: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 352: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 353: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 354: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 355: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 356: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 357: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 358: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 359: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 360: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 361: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 362: solve_daily_milp() missing 1 required positional argument: 'day'
#   Skipping day 363: solve_daily_milp() missing 1 required positional argument: 'day'
#
# ✓ Saved 0 examples to datasets_corrected\italy_test_corrected.json
#   Size: 0.00 MB
#
# ================================================================================
# GENERATING: GERMANY (train)
# ================================================================================
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[1], line 313
#     310 battery_params.soc_init = 0.5
#     312 # Train
# --> 313 train_data = generate_corrected_dataset(
#     314     dataset_name=dataset_name,
#     315     split='train',
#     316     battery_params=battery_params,
#     317     data_dir="./agentic_energy/data",
#     318     output_dir="./datasets_corrected",
#     319     max_days=None
#     320 )
#     321 all_train.extend(train_data)
#     323 # Test
#
# Cell In[1], line 161, in generate_corrected_dataset(dataset_name, split, battery_params, data_dir, output_dir, max_days)
#     159 # Load data
#     160 loader = EnergyDataLoader(region=dataset_name.upper(), data_version="actual")
# --> 161 data = loader.load_region_data()
#     163 # Split data
#     164 split_idx = int(len(data) * 0.5)
#
# File c:\Users\16467\OneDrive\Desktop\Columbia\Agentics\Another\Agentics_for_EnergyArbitrage_Battery\energy_arbitrage\agentic_energy\data_loader.py:177, in EnergyDataLoader.load_region_data(self)
#     174 if not file_path.exists():
#     175     raise FileNotFoundError(f"Data file not found: {file_path}")
# --> 177 energy_data = AG.from_csv(file_path, atype=EnergyDataRecord)
#     179 # Stamp region on each record
#     180 for state in energy_data.states:
#
# File ~\OneDrive\Desktop\Columbia\Agentics\Another\Agentics_for_EnergyArbitrage_Battery\src\agentics\core\agentics.py:317, in AG.from_csv(cls, csv_file, atype, max_rows, task_description)
#     315 for row in csv.DictReader(f):
#     316     if not max_rows or c_row < max_rows:
# --> 317         state = new_type(**row)
#     318         states.append(state)
#     319     c_row += 1
#
# File c:\Users\16467\OneDrive\Desktop\Columbia\Agentics\Another\Agentics_for_EnergyArbitrage_Battery\.venv\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 1 validation error for EnergyDataRecord
# prices
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='28,32', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/float_parsing
